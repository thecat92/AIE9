# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/fireworks/models/gpt-oss-20b"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7daa9ddf4e10>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7daa9ddf8f50>
# In plain English—and after a few tongue‑twisting experiments—a woodchuck could turn over roughly **700 pounds (≈320 kg) of material** in a single day if it were actually “chucking wood.”
# That figure comes from a playful 1988 study by wildlife biologist Richard Thomas, who compared the burrowing capacity of a woodchuck to a typical “chuck” of wood. While woodchucks don’t normally chuck timber, they’re adept at moving earth, and the volume of soil they excavate translates to the rough equivalent of about 700 pounds of wood.
#
# So, if ever a woodchuck decided to become a lumber‑jack, you’d expect it to haul around three‑quarters of a ton of wood around before needing a break!

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Request 10 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-0796b75d8f574c77a18537c6afaeda1f"}
# Request 21 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-a1904fc5954341dcafa396036617c183"}
# Request 6 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-3c24c6e77b494f0089efa4ee5c7f6e38"}
# Request 2 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-07de6d6ecfc44879be26605fcfa66579"}
# Request 14 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-e0e175c6132d4ef387e595b46b8c848f"}
# Request 16 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-a56b52778e8240ffb80815c4e8dfd8fd"}
# Request 20 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-5ea44a8921ae47c0a92c21257c6eb07f"}
# Request 19 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-023ff7b584b64a348091a884bccccec7"}
# Request 15 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-511fcb2129014bf9add9424e3bfb0590"}
# Request 4 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-35219f1fe665450cbd97f88c4112567f"}
# Request 5 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-4b2e06e582894ea6bd3cff3b72075f3a"}
# Response 13: That's the classic tongue‑twister! While there's no real sci...
# Response 18: Whether or not a wood‑chuck can actually chuck wood is a spi...
# Response 22: If we take the classic tongue‑twister literally, the answer ...
# Response 3: In the classic tongue‑twister, the answer is intentionally h...
# Response 12: Ah, the classic tongue‑twister! While no real wood‑chuck eve...
# Response 1: **Answer (Request 1)**
#
# The tongue‑twister’s answer is a p...
# Response 23: It’s a question that’s as much about tongue‑twisting as it i...
# Response 17: Ah, the age‑old riddle that turns tongues quick and imagines...
# Response 8: **The classic tongue‑twister answer:**
#
# > “A woodchuck would...
# Response 7: **Short, classic answer:**
# > *“A woodchuck would chuck as ...
# Response 11: The classic tongue‑twister never meant “scientifically” anyt...
# Response 24: In the classic “wood‑chuck” tongue‑twister, the answer is us...
# Response 9: **Short answer:** *About 700 lb (≈3.2 m³) of hardwood a day ...
